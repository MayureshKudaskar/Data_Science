# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Check whether the MPG of Cars follows Normal Distribution

# %%
car = pd.read_csv("C:/Users/Mayuresh/Desktop/ExcelR/Assignment/01 Assignments/1 Basic Statistics Level_1/Cars.csv")

# %%
car.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
sns.distplot(car.MPG, label='Cars_MPG')
plt.xlabel('MPG')
plt.ylabel('Density')
plt.legend();
# Out:
# C:\Users\Mayuresh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
car.MPG.hist()
# Out:
# <AxesSubplot:>

# %%
car.MPG.describe()
# Out:
# count    81.000000
# mean     34.422076
# std       9.131445
# min      12.101263
# 25%      27.856252
# 50%      35.152727
# 75%      39.531633
# max      53.700681
# Name: MPG, dtype: float64

# %%
#Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution

# %%
WC = pd.read_csv("C:/Users/Mayuresh/Desktop/ExcelR/Assignment/01 Assignments/1 Basic Statistics Level_1/wc-at.csv")

# %%
WC.head(10)
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84
# 5  71.85  21.68
# 6  80.90  29.08
# 7  83.40  32.98
# 8  63.50  11.44
# 9  73.20  32.22

# %%
WC.Waist.describe()
# Out:
# count    109.000000
# mean      91.901835
# std       13.559116
# min       63.500000
# 25%       80.000000
# 50%       90.800000
# 75%      104.000000
# max      121.000000
# Name: Waist, dtype: float64

# %%
WC.AT.describe()
# Out:
# count    109.000000
# mean     101.894037
# std       57.294763
# min       11.440000
# 25%       50.880000
# 50%       96.540000
# 75%      137.000000
# max      253.000000
# Name: AT, dtype: float64

# %%
sns.distplot(WC.Waist, label='WC')
plt.xlabel('Waist')
plt.ylabel('Density')
plt.legend();
# Out:
# C:\Users\Mayuresh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(WC.AT, label='WC')
plt.xlabel('AT')
plt.ylabel('Density')
plt.legend();
# Out:
# C:\Users\Mayuresh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
