# %%
import pandas as pd
import numpy as np
import pylab 
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy import stats

# %%
cutlet = pd.read_csv('/content/Cutlets.csv')

# %%
cutlet.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
cutlet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 688.0 bytes

# %%
cutlet.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
measurements = np.random.normal(loc = 7.019091, scale =0.288408 , size=35)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
measurements = np.random.normal(loc = 6.964, scale =  0.343 , size=35)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
# 2 sample test
#H0 = There is no difference in diameter
#H1 = There is difference in diameter

# %%
stats.ttest_ind(cutlet['Unit A'],cutlet['Unit B'])
# Out:
# Ttest_indResult(statistic=0.7228688704678061, pvalue=0.4722394724599501)

# %%
#hence p-value(0.472)>alpha(0.05) 
# Hence we accept H0
##There is no significant difference in the diameters of Unit A and Unit B at 5% significance level
