# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import scipy.stats as stats
import pylab

# %%
Lab = pd.read_csv('/content/LabTAT.csv')

# %%
Lab
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
Lab.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
measurements = np.random.normal(loc = 178.361, scale = 13.173  , size=120)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
measurements = np.random.normal(loc = 178.902, scale = 14.957  , size=120)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
measurements = np.random.normal(loc = 199.913, scale = 16.539  , size=120)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
measurements = np.random.normal(loc = 163.682, scale = 15.085  , size=120)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
#H0 = There is not any difference
#H1 = There is a difference
#

# %%
#Here more than 2 samples are involved Hence we used 1 way F test (Anova Test)

# %%
stats.f_oneway(Lab['Laboratory 1'],Lab['Laboratory 2'],Lab['Laboratory 3'],Lab['Laboratory 4'])
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
# p-value(2.1156708949992414e-57)<alpha(0.05), Hence reject the H0 Hypothesis.
#There is difference in average TAT among the different Laboratories at 5% significance level.
