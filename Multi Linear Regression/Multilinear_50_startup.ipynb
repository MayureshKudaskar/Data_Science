# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Read the data

# %%
startup = pd.read_csv('/content/50_Startups.csv')

# %%
startup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startup.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ##Check Null values

# %%
startup.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# **convert state data into dummy variables**

# %%
startup1= pd.get_dummies(startup,columns=['State'])

# %%
startup1.head()
# Out:
#    R&D Spend  Administration  ...  State_Florida  State_New York
# 0  165349.20       136897.80  ...              0               1
# 1  162597.70       151377.59  ...              0               0
# 2  153441.51       101145.55  ...              1               0
# 3  144372.41       118671.85  ...              0               1
# 4  142107.34        91391.77  ...              1               0
#
# [5 rows x 7 columns]

# %% [markdown]
# **Rename the col names for simplicity of usuage**

# %%
startup2=startup1.rename(columns = {'R&D Spend':'RnD', 'Administration':'Admin','Marketing Spend':'MS',
                                    'State_California':'CA','State_Florida':'FL','State_New York':'NY'})

# %%
startup2.head()
# Out:
#          RnD      Admin         MS     Profit  CA  FL  NY
# 0  165349.20  136897.80  471784.10  192261.83   0   0   1
# 1  162597.70  151377.59  443898.53  191792.06   1   0   0
# 2  153441.51  101145.55  407934.54  191050.39   0   1   0
# 3  144372.41  118671.85  383199.62  182901.99   0   0   1
# 4  142107.34   91391.77  366168.42  166187.94   0   1   0

# %% [markdown]
# **Checking for duplicates**

# %%
startup2[startup2.duplicated()].shape
# Out:
# (0, 7)

# %% [markdown]
# #Correlation Matrix

# %%
startup2.corr()
# Out:
#              RnD     Admin        MS    Profit        CA        FL        NY
# RnD     1.000000  0.241955  0.724248  0.972900 -0.143165  0.105711  0.039068
# Admin   0.241955  1.000000 -0.032154  0.200717 -0.015478  0.010493  0.005145
# MS      0.724248 -0.032154  1.000000  0.747766 -0.168875  0.205685 -0.033670
# Profit  0.972900  0.200717  0.747766  1.000000 -0.145837  0.116244  0.031368
# CA     -0.143165 -0.015478 -0.168875 -0.145837  1.000000 -0.492366 -0.515152
# FL      0.105711  0.010493  0.205685  0.116244 -0.492366  1.000000 -0.492366
# NY      0.039068  0.005145 -0.033670  0.031368 -0.515152 -0.492366  1.000000

# %% [markdown]
# #Scatterplot along with Histogram

# %%
sns.pairplot (data=startup2)

# %% [markdown]
# *building the regression model*

# %%
model1 = smf.ols('Profit~RnD+Admin+MS+CA+FL+NY',data=startup2).fit()

# %%
model1.params
# Out:
# Intercept    37633.233317
# RnD              0.806023
# Admin           -0.027004
# MS               0.026980
# CA           12492.110514
# FL           12690.899307
# NY           12450.223495
# dtype: float64

# %%
print(model1.tvalues, '\n', model1.pvalues)
# Out:
# Intercept     7.417409
# RnD          17.368580
# Admin        -0.517012
# MS            1.573889
# CA            5.099242
# FL            4.654306
# NY            5.007401
# dtype: float64
#  Intercept    2.807645e-09
# RnD          2.578772e-21
# Admin        6.077373e-01
# MS           1.226769e-01
# CA           6.942555e-06
# FL           2.992503e-05
# NY           9.409010e-06
# dtype: float64

# %%
(model1.rsquared,model1.rsquared_adj)
# Out:
# (0.9507524843355148, 0.945156175737278)

# %% [markdown]
# #Calculating VIF to check collinearity

# %%
rsq_RnD = smf.ols('RnD~Admin+MS',data=startup2).fit().rsquared  
vif_RnD = 1/(1-rsq_RnD) 

rsq_Admin = smf.ols('Admin~RnD+MS',data=startup2).fit().rsquared  
vif_Admin = 1/(1-rsq_Admin) 

rsq_MS = smf.ols('MS~RnD+Admin',data=startup2).fit().rsquared  
vif_MS = 1/(1-rsq_MS) 


d1 = {'Variables':['RnD','Admin','MS'],'VIF':[vif_RnD,vif_Admin,vif_MS]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0       RnD  2.468903
# 1     Admin  1.175091
# 2        MS  2.326773

# %% [markdown]
# **All VIF values are less than 20, there are no collinear variables**

# %% [markdown]
# ## Q-Q plot for checking the normality of residuals

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model1.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model1.resid<-30000))
# Out:
# [array([49])]

# %% [markdown]
# Homoscedasticity(checking variable is constant in residual)

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model1.fittedvalues),
            get_standardized_values(model1.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# **Residual plot is not following any pattern, so its a good plot**

# %% [markdown]
# # Residual Vs Regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model1, "RnD", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model1, "Admin", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model1, "MS", fig=fig)
plt.show()

# %% [markdown]
# # Identifying the outliers using cook's distance

# %%
model_influence = model1.get_influence()
(c, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(startup2)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
(np.argmax(c),np.max(c))
# Out:
# (49, 0.22625094501509233)

# %%
startup2[startup2.index.isin([49])]
# Out:
#     RnD     Admin        MS   Profit  CA  FL  NY
# 49  0.0  116983.8  45173.06  14681.4   1   0   0

# %%
startup3=startup2.drop(startup2.index[[49]],axis=0).reset_index()

# %%
startup3 = startup3.drop(['index'],axis=1)

# %%
model2 = smf.ols('Profit~RnD+Admin+MS+CA+FL+NY',data=startup3).fit()

# %%
(model2.rsquared,model2.rsquared_adj)
# Out:
# (0.9618082858227786, 0.9573673888254273)

# %%
model_influence = model2.get_influence()
(c, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(startup3)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
(np.argmax(c),np.max(c))
# Out:
# (48, 0.24352817571403806)

# %%
startup3[startup3.index.isin([48])]
# Out:
#        RnD     Admin   MS    Profit  CA  FL  NY
# 48  542.05  51743.15  0.0  35673.41   0   0   1

# %%
startup4=startup3.drop(startup3.index[[48]],axis=0).reset_index()

# %%
startup4 = startup4.drop(['index'],axis=1)

# %%
model3 = smf.ols('Profit~RnD+Admin+MS+CA+FL+NY',data=startup4).fit()

# %%
(model3.rsquared,model3.rsquared_adj)
# Out:
# (0.9628371102993712, 0.9584129567635821)

# %% [markdown]
# # As there is only slight change in R value in model 3 from model 2, we will not delete any further data point and consider model 3 as the final model

# %% [markdown]
# **Checking the model by predicting the profit of the same data set and comparing it with actual values**

# %%
pred_profit = pd.DataFrame (model3.predict(startup4), columns=['Predict_Profit'])

# %%
pred_profit.head()
# Out:
#    Predict_Profit
# 0   189087.074698
# 1   186183.370112
# 2   180288.581217
# 3   172087.545967
# 4   171206.768166

# %%
Actual_Profit = startup4['Profit']

# %%
pred_profit1 = pd.concat([Actual_Profit, pred_profit], axis=1)

# %%
pred_profit1.head()
# Out:
#       Profit  Predict_Profit
# 0  192261.83   189087.074698
# 1  191792.06   186183.370112
# 2  191050.39   180288.581217
# 3  182901.99   172087.545967
# 4  166187.94   171206.768166

# %%
Error = pd.DataFrame (((pred_profit1['Predict_Profit']- pred_profit1['Profit'])/pred_profit1['Profit']), columns=['Error'])

# %%
result = pd.concat ([pred_profit1, Error], axis=1)

# %%
result.head()
# Out:
#       Profit  Predict_Profit     Error
# 0  192261.83   189087.074698 -0.016513
# 1  191792.06   186183.370112 -0.029244
# 2  191050.39   180288.581217 -0.056330
# 3  182901.99   172087.545967 -0.059127
# 4  166187.94   171206.768166  0.030200

# %%
result.style.format({'Profit': "{:.2f}",'Predict_Profit': "{:.2f}",'Error': "{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Profit</th>        <th class="col_heading level0 col1" >Predict_Profit</th>        <th class="col_heading level0 col2" >Error</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row0_col0" class="data row0 col0" >192261.83</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row0_col1" class="data row0 col1" >189087.07</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row0_col2" class="data row0 col2" >-1.65%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row1_col0" class="data row1 col0" >191792.06</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row1_col1" class="data row1 col1" >186183.37</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row1_col2" class="data row1 col2" >-2.92%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row2_col0" class="data row2 col0" >191050.39</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row2_col1" class="data row2 col1" >180288.58</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row2_col2" class="data row2 col2" >-5.63%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row3_col0" class="data row3 col0" >182901.99</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row3_col1" class="data row3 col1" >172087.55</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row3_col2" class="data row3 col2" >-5.91%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row4_col0" class="data row4 col0" >166187.94</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row4_col1" class="data row4 col1" >171206.77</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row4_col2" class="data row4 col2" >3.02%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row5_col0" class="data row5 col0" >156991.12</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row5_col1" class="data row5 col1" >163039.18</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row5_col2" class="data row5 col2" >3.85%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row6_col0" class="data row6 col0" >156122.51</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row6_col1" class="data row6 col1" >158709.12</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row6_col2" class="data row6 col2" >1.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row7_col0" class="data row7 col0" >155752.60</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row7_col1" class="data row7 col1" >157770.47</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row7_col2" class="data row7 col2" >1.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row8_col0" class="data row8 col0" >152211.77</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row8_col1" class="data row8 col1" >150142.26</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row8_col2" class="data row8 col2" >-1.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row9_col0" class="data row9 col0" >149759.96</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row9_col1" class="data row9 col1" >155379.92</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row9_col2" class="data row9 col2" >3.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row10_col0" class="data row10 col0" >146121.95</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row10_col1" class="data row10 col1" >135856.20</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row10_col2" class="data row10 col2" >-7.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row11_col0" class="data row11 col0" >144259.40</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row11_col1" class="data row11 col1" >137564.58</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row11_col2" class="data row11 col2" >-4.64%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row12_col0" class="data row12 col0" >141585.52</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row12_col1" class="data row12 col1" >128838.17</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row12_col2" class="data row12 col2" >-9.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row13_col0" class="data row13 col0" >134307.35</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row13_col1" class="data row13 col1" >128054.92</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row13_col2" class="data row13 col2" >-4.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row14_col0" class="data row14 col0" >132602.65</td>
#                         <td id="T_ab21e5e8_c47b_11eb_8c5c_0242ac1c0002row14_col1" class="data row14 col1" >147711.86</td>
#                         <td

# %%
result.Error.mean()
# Out:
# 0.004337744560180083

# %% [markdown]
# **Since the mean of all the error values is close to 0, hence we can say regression equation for forecating is working well.**
